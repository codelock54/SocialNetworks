# %%
import SocialNetworks

# %%
# graph = {
#     'A': ['B', 'C', 'D'],
#     'B': ['A', 'E', 'F'],
#     'C': ['A', 'G', 'H'],
#     'D': ['A', 'I'],
#     'E': ['B', 'J', 'K'],
#     'F': ['B', 'L'],
#     'G': ['C', 'M', 'N'],
#     'H': ['C', 'O'],
#     'I': ['D', 'P', 'Q'],
#     'J': ['E', 'R'],
#     'K': ['E'],
#     'L': ['F'],
#     'M': ['G'],
#     'N': ['G'],
#     'O': ['H'],
#     'P': ['I'],
#     'Q': ['I'],
#     'R': ['J'],
#     'S': ['T', 'U'],
#     'T': ['S', 'V'],
#     'U': ['S'],
#     'V': ['T']
# }

# %%
friends = SocialNetworks.SocialNetwork()

# %%
adjacency_list = friends.read_adjacency_list_from_file('lista_adyacencia.txt')

# %%
friends.load_adjacency_list(adjacency_list)

# %%
friends.create_adList()
# Out:
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 1, column: 18, offset: 17} for query: 'MATCH (n) RETURN id(n) AS id'
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 1, column: 33, offset: 32} for query: 'MATCH (a)-[:FRIEND]->(b) RETURN id(a) AS a, id(b) AS b'
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: The query used a deprecated function: `id`.} {position: line: 1, column: 45, offset: 44} for query: 'MATCH (a)-[:FRIEND]->(b) RETURN id(a) AS a, id(b) AS b'
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 friends.create_adList()
#
# File ~/Documents/ESAN/Mate Discreta/Project/SocialNetworks.py:562, in SocialNetwork.create_adList(self, filename)
#     560 for i in range(len(self.V)):
#     561     letra = string.ascii_uppercase[i]
# --> 562     amigos = [string.ascii_uppercase[j] for j in self.L[i]]
#     563     file.write(f"{letra}: {', '.join(amigos)}\n")
#
# IndexError: string index out of range

# %%
friends.print_list()

# %%
friends.plot_friends()

# %%
friends.find_friend_groups()

# %%
person1 = "Z"
person2 = "X"
friends.add_friend(person1, person2)

# %%
friends.plot_friends()

# %%
print("Number of friend groups (DFS):", friends.find_friend_groups( use_dfs=True))

print("Number of friend groups (BFS):", friends.find_friend_groups(use_dfs=False))
# Out:
# Number of friend groups (DFS): 4
# Number of friend groups (BFS): 4

# %%
friends.recommend_friends()
# Out:
# {'A': ['E', 'I', 'F'],
#  'B': ['D', 'J', 'K', 'L'],
#  'C': ['O', 'N', 'M'],
#  'D': ['B', 'P', 'Q'],
#  'E': ['R', 'F', 'A'],
#  'F': ['E', 'A'],
#  'G': ['H'],
#  'H': ['G'],
#  'I': ['R', 'A'],
#  'J': ['B', 'K', 'Q'],
#  'K': ['B', 'J'],
#  'L': ['B'],
#  'M': ['N', 'C'],
#  'N': ['M', 'C'],
#  'O': ['C'],
#  'P': ['D', 'Q'],
#  'Q': ['D', 'J', 'P'],
#  'R': ['E', 'I'],
#  'S': ['V'],
#  'T': ['U'],
#  'U': ['T'],
#  'V': ['S'],
#  'Z': [],
#  'X': []}

# %%
popular_friends = friends.most_popular_friend()

if popular_friends:
    for person, num_friends in popular_friends:
        print(f"El amigo más popular es {person} con {num_friends} amigos.")
else:
    print("No se encontraron amigos.")
# Out:
# El amigo más popular es B con 3 amigos.
# El amigo más popular es E con 3 amigos.
# El amigo más popular es G con 3 amigos.
# El amigo más popular es I con 3 amigos.

# %%
path = friends.shortest_path( 'A', 'P')
print(f"El camino más corto de A a P es: {path}")
# Out:
# El camino más corto de A a P es: ['A', 'D', 'I', 'P']

# %%
cycle = friends.has_cycle()

if cycle:
    print(f"¡Se ha detectado un ciclo en la red de amigos! Los nodos en el ciclo son: {', '.join(cycle)}")
else:
    print("No hay ciclos en la red de amigos.")
# Out:
# ¡Se ha detectado un ciclo en la red de amigos! Los nodos en el ciclo son: A, B, E, J, R, Q, I, D, A

# %%
friends.remove_friend('A', 'C')
